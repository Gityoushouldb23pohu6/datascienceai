# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3,4])

# %%
plt.ylabel('Numbers')
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.show()

# %%
import numpy as np
x=np.linspace(0,2,10)
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label="cubic")
plt.xlabel("Im x")
plt.ylabel("Im y")
plt.title("simple plot")
plt.legend()
plt.show()

# %%
x=np.linspace(0,100,20)
plt.plot(x,np.cos(x),label="cos")
plt.plot(x,np.tan(x),label="tan")
plt.xlabel("Imx")
plt.ylabel("Imy ")
plt.show()

plt.axis()
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.plot([1,4,6,2],[5,6,2,8],'b-')
plt.axis([0,7,0,10])
plt.show()

# %%
t=np.arange(0,5,0.2)
plt.plot(t,t**2,'r--',t,np.sin(t),'bs',t,t**4,'g^')
plt.show()

# %%
x1= np.arange(6)
fig ,ax= plt.subplots(2)
ax[0].plot(x1,np.sin(x1),'b--')
ax[1].plot(x1,np.cos(x1),'b--')
plt.show()

# %%
x= np.linspace(5,100,20)
f,ax= plt.subplots(3)
ax[0].plot(x,np.tan(x),'ro')
ax[1].plot(x,np.cos(x),'b-')
ax[2].plot(x,np.sin(x),'y--')
plt.show()

# %%
fig= plt.figure()
x2= np.linspace (0,5,10)
y2= x2**2
axes= fig.add_axes([0.1,0.1,0.8,0.8])

# %%
axes.plot(x2,y2,'r')
axes.set_xlabel("Iam x")
axes.set_ylabel("Iam y")
axes.set_title("title ")
plt.show()

# %%
f= plt.figure()
a= f.add_axes([0.5,0.5 ,1,1])
a.plot(x1,np.sin(x1),'bo')
a.set_xlabel("independent")
a.set_ylabel("dependent ")
a.set_title("MATPLTR")
plt.show()

# %%
axnew=plt.axes()

# %%
axnew.plot(x1,np.tan(x1))
plt.show()

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

# %%
ax1.plot(x,np.sin(x*x),'r--')
ax2.plot(x,np.sin(x**3),'r--')
ax3.plot(x,np.sin(x**8),'r--')
ax4.plot(x,np.sin(x**9),'r--')
plt.show()

# %%
f=plt.figure()
axn= f.add_axes([0.1,0.1,0.9,0.9])
axn.plot(x1,np.sin(x1**2),'b')
plt.show()

# %%
a=plt.axes()
a.plot(x1,np.cos(x1**4),'b')
plt.show()

# %%
f=plt.figure()
a= f.add_subplot(2,1,1)
b=f.add_subplot(2,1,2)
a.plot(x1,np.tan(x1),'b-')
b.plot(x1,np.sin(x1),'r-')
plt.show()

# %%
plt.plot([1,2,3,4],'b--')
plt.show()

# %%
x3=np.arange(9,99,1)
plt.plot(x3,[x**4 for x in x3],'ro')
plt.show()

# %%
x1=range(1,5)

plt.plot(x1,[x**5 for x in x1])
plt.plot(x1,[x**8 for x in x1])
plt.plot(x1,[x*3 for x in x1])
plt.show()

# %%
f.savefig('fig1.png')

# %%
from IPython.display import Image
Image('fig1.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %%
a=plt.axes()
x=np.linspace(4,100,1000)
a.plot(x, [  np.sin(i) for i in x ],'b-')
plt.show()

# %%
x3= np.linspace (0,10,30)
y3=[ np.tan(i) for i in  x3]
plt.plot(x3,y3,'o',color='black')
plt.show()

# %%
data = np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
data= np.random.randn(8)
plt.hist(data)

plt.show()

# %%
dat= [3,4,1,4,2]
plt.bar(range(len(dat)),dat)
plt.show()

# %%
data = [5,4,2,1,5]
plt.bar(data,range(len(data)))
plt.show()

# %%
data=np.random.rand(5)

# %%
data
# Out:
# array([0.09269992, 0.53137831, 0.38381561, 0.60652259, 0.2798221 ])

# %%
plt.barh(data,[i**7 for i in data])
plt.show()

# %%
A= [15,20,4,33]
B= [3,4,55,22]
z2= range(4)
plt.bar(z2,A,color='b')
plt.bar(z2,B,color='r',bottom = A)
plt.show()

# %%
A= np.linspace(4,100,9)
B= np.linspace(2,99,9)
z=range(9)

# %%
plt.bar(z,A,color='b')
plt.bar(z,B,color='g',bottom = A)
plt.show()

# %%
plt.figure(figsize=(7,7))
x10=[70,20,30,80,100]
labels=['com','net','utu','yo','utll']
plt.pie(x10,labels=labels)
plt.show()

# %%
plt.figure (figsize=(5,6))
x=[1,2,3,4,5]
plt.pie(x,labels=["one",'two','thre','four','five'])
plt.show()

# %%
data3= np.random.randn(100)
plt.boxplot(data3)
plt.show()

# %%
x= range(1,6)
y12= [1,3,45,2,5]
plt.fill_between(x,y12)
plt.show()

# %%
x=range(10) 
y= np.random.randn(10)
plt.stackplot(x,y)
plt.show()

# %%
plt.style.use('seaborn-bright')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File C:\anaconda\Lib\site-packages\matplotlib\__init__.py:870, in _rc_params_in_file(fname, transform, fail_on_error)
#     869 rc_temp = {}
# --> 870 with _open_file_or_url(fname) as fd:
#     871     try:
#
# File C:\anaconda\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File C:\anaconda\Lib\site-packages\matplotlib\__init__.py:847, in _open_file_or_url(fname)
#     846 fname = os.path.expanduser(fname)
# --> 847 with open(fname, encoding='utf-8') as f:
#     848     yield f
#
# ...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
x=np.linspace(1,1000,100)
plt.plot(x)
plt.grid(True)
plt.show()

# %%
x5= np.arange(1,10)
plt.plot(x5)
plt.axis()
plt.show()

# %%
plt.axis([0,10,0,12])
# Out:
# (0.0, 10.0, 0.0, 12.0)

# %%
plt.show()

# %%
plt.plot(np.linspace(4,55,100))

         
plt.xlim([2,4])
plt.ylim([0,12])
plt.show()

# %%
u=[5,2,1,4,5,6,7,8,1,2,4]
plt.plot(u)
plt.xticks([2,4,6,3,8,9])
plt.yticks([2,3,4,5,6,8])
plt.show()

# %%
plt.plot(np.linspace(9,100,77))
plt.xticks([1,2,3,4,5,6])
plt.yticks([3,4,1,2,5,7,5])
plt.show()

# %%
plt.plot([1,2,3,4,5,6])
plt.xlabel("its your x")
plt.ylabel("its your yif")
plt.show()
